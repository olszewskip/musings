# %%
import urllib.request
import bs4 as bs

import datetime
import dateutil.parser
import time
from pathlib import Path
import re

# %% [markdown]
# ### Each paper on arXive has assigned to it a single primary category, e.g. *cs* (Computer Science), *econ* (Economics), etc. We can retrieve the list of existing categories from the API.

# %%
categories_file = "categories.txt"

# %%
# The short raw xml meta-metadata contains info about the
# accesible arXiv categories of topics called 'sets'.
# You may go to the address Yourself.
# Lets dump it to the labels_file

if not Path(categories_file).is_file() :
    
    xml_query_labels = "http://export.arxiv.org/oai2?verb=ListSets"
    sauce = urllib.request.urlopen(xml_query_labels).read()

    with open(categories_file, "w") as dump:
        dump.write(str(sauce))

# %%
# Read from labels_file the raw xml.
# Create a dict {'cs': 'Computer Science', 'econ': 'Economics', etc}.

with open(categories_file) as readfrom:
    soup = bs.BeautifulSoup(readfrom.read(), 'lxml')

sets = soup.find_all("set")

categories = {}

for set_ in sets:
    categories[set_.setspec.string] = set_.setname.string

# %% [markdown]
# ### The matter of categories is actually more messy. The primary categrization chosen by an author may be finer, e.g. *physics.astro-ph* (Physics: Astrophysics) instead of just *physics*. On top of that a paper may be assigned into secondary categories, again of potentially differing granulaties. A paper may for example have *econ.th* (Economics: Theoretical Economics) as its primary category, and *stat* as a secondary category without finer specification like *stat.me* (Statistics: Metodology), and *q-fin.ec* (Quantitative Finance: Economics) as an another secondary category.
#
# ### What we have retrieved is just the list of categories that can be used in the API queries. Apparently physics enthusiasts get more options.

# %%
categories
# Out:
# {'cs': 'Computer Science',
#  'econ': 'Economics',
#  'eess': 'Electrical Engineering and Systems Science',
#  'math': 'Mathematics',
#  'physics': 'Physics',
#  'physics:astro-ph': 'Astrophysics',
#  'physics:cond-mat': 'Condensed Matter',
#  'physics:gr-qc': 'General Relativity and Quantum Cosmology',
#  'physics:hep-ex': 'High Energy Physics - Experiment',
#  'physics:hep-lat': 'High Energy Physics - Lattice',
#  'physics:hep-ph': 'High Energy Physics - Phenomenology',
#  'physics:hep-th': 'High Energy Physics - Theory',
#  'physics:math-ph': 'Mathematical Physics',
#  'physics:nlin': 'Nonlinear Sciences',
#  'physics:nucl-ex': 'Nuclear Experiment',
#  'physics:nucl-th': 'Nuclear Theory',
#  'physics:physics': 'Physics (Other)',
#  'physics:quant-ph': 'Quantum Physics',
#  'q-bio': 'Quantitative Biology',
#  'q-fin': 'Quantitative Finance',
#  'stat': 'Statistics'}

# %% [markdown]
# ### Lets exclude the *physics* as a single category.

# %%
cats = {cat: cat_name for (cat, cat_name) in categories.items() if cat != 'physics'}

# %% [markdown]
# ### Say we wanna retrieve metadata of papers in Statistics published in May 2008.

# %%
# This function talks to You and tries to dump the xml into a local file
# It takes its sweet time because of poor timeout-handling
# Try e.g. harvest_data("2008-05-01","2008-06-01", 'stat')

def harvest_data(isoday_0, isoday_1, cat='all', by_days=1, overwrite_the_file=False, file_name=None, verbose=True) -> int :
    
    def verboseprint(text):
        if verbose:
            print(text)
    
    date_0 = dateutil.parser.parse(isoday_0).date()
    date_1 = dateutil.parser.parse(isoday_1).date()
    timestep  = datetime.timedelta(by_days-1)
    
    if date_1 < date_0:
        raise ValueError("Second date must be later than the first")
    
    if not file_name:
        # create a file with an overly descriptive name
        file = f"arXivMeta_{cat.replace(':','--')}_from_{date_0}_to_{date_1}.txt"
    else:
        file = file_name
        
    verboseprint(f"Writing to {file}")
    
    def clear_content(file) : # in place
        dump = open(file, 'w')
        dump.truncate(0)
        dump.close()

    if Path(file).is_file() :
        
        if overwrite_the_file :
            clear_content(file)
            verboseprint("The file was overwritten")
        else :
            verboseprint("The file already exists")
            return None
            
    else :
        verboseprint("The file will be created")


    
    def get_data_slice(date_from, date_until) -> int :
        
        records_count = -1
        
        if cat == 'all':
            xml_query= f"""
            http://export.arxiv.org/oai2?verb=ListRecords&from={date_from}&until={date_until}&metadataPrefix=arXiv
            """
        else:
            xml_query= f"""
            http://export.arxiv.org/oai2?verb=ListRecords&from={date_from}&until={date_until}&set={cat}&metadataPrefix=arXiv
            """
        
        def from_query_to_file() -> int :
            
            sauce = urllib.request.urlopen(xml_query).read()
            text = str(sauce)
            records = bs.BeautifulSoup(text, 'lxml').find_all("record")
            
            with open(file, "a") as dump: # 'append' mode
                dump.write(text)
                verboseprint(f"Dumped {cat} from {date_from} to {date_until}, {len(records)} records")
            
            return len(records)
        
        # try once
        try:
            records_count = from_query_to_file()

        except urllib.error.HTTPError:

            # wait and try the secod time
            time.sleep(10)
            try:
                records_count = from_query_to_file()

            except urllib.error.HTTPError:                
                verboseprint(f"Failed {cat} at date_from={date_from}, date_until={date_until}")

        return records_count

    
    # loop over dates and write data-slices to file
    date_from = date_0
    
    records = 0

    while date_from <= date_1:

        date_until = min(date_from + timestep, date_1)
        
        # get the data
        new_records = get_data_slice(date_from, date_until)

        if new_records == -1 :
            break
            
        records = records + new_records
        date_from = date_until + datetime.timedelta(days=1)

    
    verboseprint(f"Retrieved {records} records\n")

    return records

# %% [markdown]
# ### There we go.  Seems like there was about one paper per day in statistics in the May of 2008

# %%
harvest_data("2008-05-01","2008-06-01", 'stat', by_days = 32, overwrite_the_file=True, file_name='test.txt')
# Out:
# Writing to test.txt
# The file was overwritten
# Dumped stat from 2008-05-01 to 2008-06-01, 34 records
# Retrieved 34 records
# 34

# %% [markdown]
# ### It's slow. The *by_days* argument controls by how big a chunks we are getting the data.  The bigger it is the faster we go, but when the number of records maxes out at 1000, it means that some of the data was not retrieved. Each chunk takes about a dozen seconds or more due to time-out.

# %% [markdown]
# ### 'Economics' and ''Electrical Engineering and Systems Science' records begin only in 2017. Let's ignore them.

# %%
year=2016
for cat in ['econ', 'eess']:
    print(cat, f"in year {year}:",\
          harvest_data(f"{year}-01-01",f"{year}-12-31",\
                       cat, by_days = 370,\
                       overwrite_the_file=True, file_name='test.txt',\
                       verbose=False)
         )
# Out:
# econ in year 2016: 0
# eess in year 2016: 0

# %%
del cats['econ']
del cats['eess']
cats
# Out:
# {'cs': 'Computer Science',
#  'math': 'Mathematics',
#  'physics:astro-ph': 'Astrophysics',
#  'physics:cond-mat': 'Condensed Matter',
#  'physics:gr-qc': 'General Relativity and Quantum Cosmology',
#  'physics:hep-ex': 'High Energy Physics - Experiment',
#  'physics:hep-lat': 'High Energy Physics - Lattice',
#  'physics:hep-ph': 'High Energy Physics - Phenomenology',
#  'physics:hep-th': 'High Energy Physics - Theory',
#  'physics:math-ph': 'Mathematical Physics',
#  'physics:nlin': 'Nonlinear Sciences',
#  'physics:nucl-ex': 'Nuclear Experiment',
#  'physics:nucl-th': 'Nuclear Theory',
#  'physics:physics': 'Physics (Other)',
#  'physics:quant-ph': 'Quantum Physics',
#  'q-bio': 'Quantitative Biology',
#  'q-fin': 'Quantitative Finance',
#  'stat': 'Statistics'}

# %% [markdown]
# ### Lets download the metadata one year at a time, one category at a time.

# %%
year = '2013'

for cat in cats:
    harvest_data(f"{year}-01-01", f"{year}-12-31", cat, by_days=8)
# Out:
# Writing to arXivMeta_cs_from_2013-01-01_to_2013-12-31.txt
# The file already exists
# Writing to arXivMeta_math_from_2013-01-01_to_2013-12-31.txt
# The file already exists
# Writing to arXivMeta_physics--astro-ph_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Dumped physics:astro-ph from 2013-01-01 to 2013-01-08, 106 records
# Dumped physics:astro-ph from 2013-01-09 to 2013-01-16, 152 records
# Dumped physics:astro-ph from 2013-01-17 to 2013-01-24, 139 records
# Dumped physics:astro-ph from 2013-01-25 to 2013-02-01, 123 records
# Dumped physics:astro-ph from 2013-02-02 to 2013-02-09, 107 records
# Dumped physics:astro-ph from 2013-02-10 to 2013-02-17, 101 records
# Dumped physics:astro-ph from 2013-02-18 to 2013-02-25, 121 records
# Dumped physics:astro-ph from 2013-02-26 to 2013-03-05, 152 records
# Dumped physics:astro-ph from 2013-03-06 to 2013-03-13, 170 records
# Dumped physics:astro-ph from 2013-03-14 to 2013-03-21, 149 records
# Dumped physics:astro-ph from 2013-03-22 to 2013-03-29, 112 records
# Dumped physics:astro-ph from 2013-03-30 to 2013-04-06, 98 records
# Dumped physics:astro-ph from 2013-04-07 to 2013-04-14, 116 records
# Dumped physics:astro-ph from 2013-04-15 to 2013-04-22, 121 records
# Dumped physics:astro-ph from 2013-04-23 to 2013-04-30, 121 records
# Dumped physics:astro-ph from 2013-05-01 to 2013-05-08, 103 records
# Dumped physics:astro-ph from 2013-05-09 to 2013-05-16, 114 records
# Dumped physics:astro-ph from 2013-05-17 to 2013-05-24, 101 records
# Dumped physics:astro-ph from 2013-05-25 to 2013-06-01, 583 records
# Dumped physics:astro-ph from 2013-06-02 to 2013-06-09, 105 records
# Dumped physics:astro-ph from 2013-06-10 to 2013-06-17, 161 records
# Dumped physics:astro-ph from 2013-06-18 to 2013-06-25, 122 records
# Dumped physics:astro-ph from 2013-06-26 to 2013-07-03, 138 records
# Dumped physics:astro-ph from 2013-07-04 to 2013-07-11, 131 records
# Dumped physics:astro-ph from 2013-07-12 to 2013-07-19, 174 records
# Dumped physics:astro-ph from 2013-07-20 to 2013-07-27, 141 records
# Dumped physics:astro-ph from 2013-07-28 to 2013-08-04, 141 records
# Dumped physics:astro-ph from 2013-08-05 to 2013-08-12, 201 records
# Dumped physics:astro-ph from 2013-08-13 to 2013-08-20, 114 records
# Dumped physics:astro-ph from 2013-08-21 to 2013-08-28, 138 records
# Dumped physics:astro-ph from 2013-08-29 to 2013-09-05, 137 records
# Dumped physics:astro-ph from 2013-09-06 to 2013-09-13, 127 records
# Dumped physics:astro-ph from 2013-09-14 to 2013-09-21, 102 records
# Dumped physics:astro-ph from 2013-09-22 to 2013-09-29, 107 records
# Dumped physics:astro-ph from 2013-09-30 to 2013-10-07, 172 records
# Dumped physics:astro-ph from 2013-10-08 to 2013-10-15, 163 records
# Dumped physics:astro-ph from 2013-10-16 to 2013-10-23, 124 records
# Dumped physics:astro-ph from 2013-10-24 to 2013-10-31, 174 records
# Dumped physics:astro-ph from 2013-11-01 to 2013-11-08, 115 records
# Dumped physics:astro-ph from 2013-11-09 to 2013-11-16, 118 records
# Dumped physics:astro-ph from 2013-11-17 to 2013-11-24, 123 records
# Dumped physics:astro-ph from 2013-11-25 to 2013-12-02, 108 records
# Dumped physics:astro-ph from 2013-12-03 to 2013-12-10, 151 records
# Dumped physics:astro-ph from 2013-12-11 to 2013-12-18, 176 records
# Dumped physics:astro-ph from 2013-12-19 to 2013-12-26, 74 records
# Dumped physics:astro-ph from 2013-12-27 to 2013-12-31, 42 records
# Retrieved 6368 records
#
# Writing to arXivMeta_physics--cond-mat_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Dumped physics:cond-mat from 2013-01-01 to 2013-01-08, 251 records
# Dumped physics:cond-mat from 2013-01-09 to 2013-01-16, 319 records
# Dumped physics:cond-mat from 2013-01-17 to 2013-01-24, 248 records
# Dumped physics:cond-mat from 2013-01-25 to 2013-02-01, 277 records
# Dumped physics:cond-mat from 2013-02-02 to 2013-02-09, 244 records
# Dumped physics:cond-mat from 2013-02-10 to 2013-02-17, 214 records
# Dumped physics:cond-mat from 2013-02-18 to 2013-02-25, 288 records
# Dumped physics:cond-mat from 2013-02-26 to 2013-03-05, 270 records
# Dumped physics:cond-mat from 2013-03-06 to 2013-03-13, 249 records
# Dumped physics:cond-mat from 2013-03-14 to 2013-03-21, 329 records
# Dumped physics:cond-mat from 2013-03-22 to 2013-03-29, 257 records
# Dumped physics:cond-mat from 2013-03-30 to 2013-04-06, 212 records
# Dumped physics:cond-mat from 2013-04-07 to 2013-04-14, 247 records
# Dumped physics:cond-mat from 2013-04-15 to 2013-04-22, 238 records
# Dumped physics:cond-mat from 2013-04-23 to 2013-04-30, 287 records
# Dumped physics:cond-mat from 2013-05-01 to 2013-05-08, 255 records
# Dumped physics:cond-mat from 2013-05-09 to 2013-05-16, 249 records
# Dumped physics:cond-mat from 2013-05-17 to 2013-05-24, 234 records
# Dumped physics:cond-mat from 2013-05-25 to 2013-06-01, 1000 records
# Dumped physics:cond-mat from 2013-06-02 to 2013-06-09, 205 records
# Dumped physics:cond-mat from 2013-06-10 to 2013-06-17, 263 records
# Dumped physics:cond-mat from 2013-06-18 to 2013-06-25, 306 records
# Dumped physics:cond-mat from 2013-06-26 to 2013-07-03, 277 records
# Dumped physics:cond-mat from 2013-07-04 to 2013-07-11, 272 records
# Dumped physics:cond-mat from 2013-07-12 to 2013-07-19, 289 records
# Dumped physics:cond-mat from 2013-07-20 to 2013-07-27, 235 records
# Dumped physics:cond-mat from 2013-07-28 to 2013-08-04, 217 records
# Dumped physics:cond-mat from 2013-08-05 to 2013-08-12, 298 records
# Dumped physics:cond-mat from 2013-08-13 to 2013-08-20, 257 records
# Dumped physics:cond-mat from 2013-08-21 to 2013-08-28, 252 records
# Dumped physics:cond-mat from 2013-08-29 to 2013-09-05, 309 records
# Dumped physics:cond-mat from 2013-09-06 to 2013-09-13, 294 records
# Dumped physics:cond-mat from 2013-09-14 to 2013-09-21, 211 records
# Dumped physics:cond-mat from 2013-09-22 to 2013-09-29, 271 records
# Dumped physics:cond-mat from 2013-09-30 to 2013-10-07, 287 records
# Dumped physics:cond-mat from 2013-10-08 to 2013-10-15, 278 records
# Dumped physics:cond-mat from 2013-10-16 to 2013-10-23, 259 records
# Dumped physics:cond-mat from 2013-10-24 to 2013-10-31, 350 records
# Dumped physics:cond-mat from 2013-11-01 to 2013-11-08, 231 records
# Dumped physics:cond-mat from 2013-11-09 to 2013-11-16, 293 records
# Dumped physics:cond-mat from 2013-11-17 to 2013-11-24, 224 records
# Dumped physics:cond-mat from 2013-11-25 to 2013-12-02, 273 records
# Dumped physics:cond-mat from 2013-12-03 to 2013-12-10, 315 records
# Dumped physics:cond-mat from 2013-12-11 to 2013-12-18, 312 records
# Dumped physics:cond-mat from 2013-12-19 to 2013-12-26, 190 records
# Dumped physics:cond-mat from 2013-12-27 to 2013-12-31, 71 records
# Retrieved 12707 records
#
# Writing to arXivMeta_physics--gr-qc_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Dumped physics:gr-qc from 2013-01-01 to 2013-01-08, 61 records
# Dumped physics:gr-qc from 2013-01-09 to 2013-01-16, 83 records
# Dumped physics:gr-qc from 2013-01-17 to 2013-01-24, 53 records
# Dumped physics:gr-qc from 2013-01-25 to 2013-02-01, 55 records
# Dumped physics:gr-qc from 2013-02-02 to 2013-02-09, 53 records
# Dumped physics:gr-qc from 2013-02-10 to 2013-02-17, 55 records
# Dumped physics:gr-qc from 2013-02-18 to 2013-02-25, 45 records
# Dumped physics:gr-qc from 2013-02-26 to 2013-03-05, 74 records
# Dumped physics:gr-qc from 2013-03-06 to 2013-03-13, 58 records
# Dumped physics:gr-qc from 2013-03-14 to 2013-03-21, 83 records
# Dumped physics:gr-qc from 2013-03-22 to 2013-03-29, 44 records
# Dumped physics:gr-qc from 2013-03-30 to 2013-04-06, 46 records
# Dumped physics:gr-qc from 2013-04-07 to 2013-04-14, 43 records
# Dumped physics:gr-qc from 2013-04-15 to 2013-04-22, 51 records
# Dumped physics:gr-qc from 2013-04-23 to 2013-04-30, 72 records
# Dumped physics:gr-qc from 2013-05-01 to 2013-05-08, 58 records
# Dumped physics:gr-qc from 2013-05-09 to 2013-05-16, 68 records
# Dumped physics:gr-qc from 2013-05-17 to 2013-05-24, 50 records
# Dumped physics:gr-qc from 2013-05-25 to 2013-06-01, 525 records
# Dumped physics:gr-qc from 2013-06-02 to 2013-06-09, 44 records
# Dumped physics:gr-qc from 2013-06-10 to 2013-06-17, 66 records
# Dumped physics:gr-qc from 2013-06-18 to 2013-06-25, 66 records
# Dumped physics:gr-qc from 2013-06-26 to 2013-07-03, 57 records
# Dumped physics:gr-qc from 2013-07-04 to 2013-07-11, 70 records
# Dumped physics:gr-qc from 2013-07-12 to 2013-07-19, 42 records
# Dumped physics:gr-qc from 2013-07-20 to 2013-07-27, 45 records
# Dumped physics:gr-qc from 2013-07-28 to 2013-08-04, 39 records
# Dumped physics:gr-qc from 2013-08-05 to 2013-08-12, 77 records
# Dumped physics:gr-qc from 2013-08-13 to 2013-08-20, 56 records
# Dumped physics:gr-qc from 2013-08-21 to 2013-08-28, 82 records
# Dumped physics:gr-qc from 2013-08-29 to 2013-09-05, 62 records
# Dumped physics:gr-qc from 2013-09-06 to 2013-09-13, 79 records
# Dumped physics:gr-qc from 2013-09-14 to 2013-09-21, 63 records
# Dumped physics:gr-qc from 2013-09-22 to 2013-09-29, 51 records
# Dumped physics:gr-qc from 2013-09-30 to 2013-10-07, 69 records
# Dumped physics:gr-qc from 2013-10-08 to 2013-10-15, 66 records
# Dumped physics:gr-qc from 2013-10-16 to 2013-10-23, 49 records
# Dumped physics:gr-qc from 2013-10-24 to 2013-10-31, 99 records
# Dumped physics:gr-qc from 2013-11-01 to 2013-11-08, 68 records
# Dumped physics:gr-qc from 2013-11-09 to 2013-11-16, 86 records
# Dumped physics:gr-qc from 2013-11-17 to 2013-11-24, 75 records
# Dumped physics:gr-qc from 2013-11-25 to 2013-12-02, 71 records
# Dumped physics:gr-qc from 2013-12-03 to 2013-12-10, 83 records
# Dumped physics:gr-qc from 2013-12-11 to 2013-12-18, 120 records
# Dumped physics:gr-qc from 2013-12-19 to 2013-12-26, 44 records
# Dumped physics:gr-qc from 2013-12-27 to 2013-12-31, 20 records
# Retrieved 3326 records
#
# Writing to arXivMeta_physics--hep-ex_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Dumped physics:hep-ex from 2013-01-01 to 2013-01-08, 44 records
# Dumped physics:hep-ex from 2013-01-09 to 2013-01-16, 41 records
# Dumped physics:hep-ex from 2013-01-17 to 2013-01-24, 42 records
# Dumped physics:hep-ex from 2013-01-25 to 2013-02-01, 56 records
# Dumped physics:hep-ex from 2013-02-02 to 2013-02-09, 20 records
# Dumped physics:hep-ex from 2013-02-10 to 2013-02-17, 28 records
# Dumped physics:hep-ex from 2013-02-18 to 2013-02-25, 27 records
# Dumped physics:hep-ex from 2013-02-26 to 2013-03-05, 25 records
# Dumped physics:hep-ex from 2013-03-06 to 2013-03-13, 42 records
# Dumped physics:hep-ex from 2013-03-14 to 2013-03-21, 76 records
# Dumped physics:hep-ex from 2013-03-22 to 2013-03-29, 29 records
# Dumped physics:hep-ex from 2013-03-30 to 2013-04-06, 27 records
# Dumped physics:hep-ex from 2013-04-07 to 2013-04-14, 39 records
# Dumped physics:hep-ex from 2013-04-15 to 2013-04-22, 27 records
# Dumped physics:hep-ex from 2013-04-23 to 2013-04-30, 26 records
# Dumped physics:hep-ex from 2013-05-01 to 2013-05-08, 46 records
# Dumped physics:hep-ex from 2013-05-09 to 2013-05-16, 45 records
# Dumped physics:hep-ex from 2013-05-17 to 2013-05-24, 39 records
# Dumped physics:hep-ex from 2013-05-25 to 2013-06-01, 415 records
# Dumped physics:hep-ex from 2013-06-02 to 2013-06-09, 42 records
# Dumped physics:hep-ex from 2013-06-10 to 2013-06-17, 64 records
# Dumped physics:hep-ex from 2013-06-18 to 2013-06-25, 78 records
# Dumped physics:hep-ex from 2013-06-26 to 2013-07-03, 37 records
# Dumped physics:hep-ex from 2013-07-04 to 2013-07-11, 36 records
# Dumped physics:hep-ex from 2013-07-12 to 2013-07-19, 33 records
# Dumped physics:hep-ex from 2013-07-20 to 2013-07-27, 23 records
# Dumped physics:hep-ex from 2013-07-28 to 2013-08-04, 48 records
# Dumped physics:hep-ex from 2013-08-05 to 2013-08-12, 60 records
# Dumped physics:hep-ex from 2013-08-13 to 2013-08-20, 46 records
# Dumped physics:hep-ex from 2013-08-21 to 2013-08-28, 39 records
# Dumped physics:hep-ex from 2013-08-29 to 2013-09-05, 34 records
# Dumped physics:hep-ex from 2013-09-06 to 2013-09-13, 45 records
# Dumped physics:hep-ex from 2013-09-14 to 2013-09-21, 33 records
# Dumped physics:hep-ex from 2013-09-22 to 2013-09-29, 36 records
# Dumped physics:hep-ex from 2013-09-30 to 2013-10-07, 84 records
# Dumped physics:hep-ex from 2013-10-08 to 2013-10-15, 72 records
# Dumped physics:hep-ex from 2013-10-16 to 2013-10-23, 33 records
# Dumped physics:hep-ex from 2013-10-24 to 2013-10-31, 71 records
# Dumped physics:hep-ex from 2013-11-01 to 2013-11-08, 41 records
# Dumped physics:hep-ex from 2013-11-09 to 2013-11-16, 52 records
# Dumped physics:hep-ex from 2013-11-17 to 2013-11-24, 30 records
# Dumped physics:hep-ex from 2013-11-25 to 2013-12-02, 51 records
# Dumped physics:hep-ex from 2013-12-03 to 2013-12-10, 58 records
# Dumped physics:hep-ex from 2013-12-11 to 2013-12-18, 41 records
# Dumped physics:hep-ex from 2013-12-19 to 2013-12-26, 28 records
# Dumped physics:hep-ex from 2013-12-27 to 2013-12-31, 9 records
# Retrieved 2318 records
#
# Writing to arXivMeta_physics--hep-lat_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Dumped physics:hep-lat from 2013-01-01 to 2013-01-08, 20 records
# Dumped physics:hep-lat from 2013-01-09 to 2013-01-16, 25 records
# Dumped physics:hep-lat from 2013-01-17 to 2013-01-24, 24 records
# Dumped physics:hep-lat from 2013-01-25 to 2013-02-01, 19 records
# Dumped physics:hep-lat from 2013-02-02 to 2013-02-09, 12 records
# Dumped physics:hep-lat from 2013-02-10 to 2013-02-17, 8 records
# Dumped physics:hep-lat from 2013-02-18 to 2013-02-25, 7 records
# Dumped physics:hep-lat from 2013-02-26 to 2013-03-05, 17 records
# Dumped physics:hep-lat from 2013-03-06 to 2013-03-13, 8 records
# Dumped physics:hep-lat from 2013-03-14 to 2013-03-21, 25 records
# Dumped physics:hep-lat from 2013-03-22 to 2013-03-29, 12 records
# Dumped physics:hep-lat from 2013-03-30 to 2013-04-06, 9 records
# Dumped physics:hep-lat from 2013-04-07 to 2013-04-14, 13 records
# Dumped physics:hep-lat from 2013-04-15 to 2013-04-22, 13 records
# Dumped physics:hep-lat from 2013-04-23 to 2013-04-30, 2 records
# Dumped physics:hep-lat from 2013-05-01 to 2013-05-08, 21 records
# Dumped physics:hep-lat from 2013-05-09 to 2013-05-16, 9 records
# Dumped physics:hep-lat from 2013-05-17 to 2013-05-24, 10 records
# Dumped physics:hep-lat from 2013-05-25 to 2013-06-01, 231 records
# Dumped physics:hep-lat from 2013-06-02 to 2013-06-09, 11 records
# Dumped physics:hep-lat from 2013-06-10 to 2013-06-17, 12 records
# Dumped physics:hep-lat from 2013-06-18 to 2013-06-25, 12 records
# Dumped physics:hep-lat from 2013-06-26 to 2013-07-03, 13 records
# Dumped physics:hep-lat from 2013-07-04 to 2013-07-11, 15 records
# Dumped physics:hep-lat from 2013-07-12 to 2013-07-19, 8 records
# Dumped physics:hep-lat from 2013-07-20 to 2013-07-27, 12 records
# Dumped physics:hep-lat from 2013-07-28 to 2013-08-04, 10 records
# Dumped physics:hep-lat from 2013-08-05 to 2013-08-12, 23 records
# Dumped physics:hep-lat from 2013-08-13 to 2013-08-20, 13 records
# Dumped physics:hep-lat from 2013-08-21 to 2013-08-28, 11 records
# Dumped physics:hep-lat from 2013-08-29 to 2013-09-05, 16 records
# Dumped physics:hep-lat from 2013-09-06 to 2013-09-13, 22 records
# Dumped physics:hep-lat from 2013-09-14 to 2013-09-21, 22 records
# Dumped physics:hep-lat from 2013-09-22 to 2013-09-29, 11 records
# Dumped physics:hep-lat from 2013-09-30 to 2013-10-07, 23 records
# Dumped physics:hep-lat from 2013-10-08 to 2013-10-15, 8 records
# Dumped physics:hep-lat from 2013-10-16 to 2013-10-23, 21 records
# Dumped physics:hep-lat from 2013-10-24 to 2013-10-31, 43 records
# Dumped physics:hep-lat from 2013-11-01 to 2013-11-08, 39 records
# Dumped physics:hep-lat from 2013-11-09 to 2013-11-16, 46 records
# Dumped physics:hep-lat from 2013-11-17 to 2013-11-24, 76 records
# Dumped physics:hep-lat from 2013-11-25 to 2013-12-02, 40 records
# Dumped physics:hep-lat from 2013-12-03 to 2013-12-10, 37 records
# Dumped physics:hep-lat from 2013-12-11 to 2013-12-18, 32 records
# Dumped physics:hep-lat from 2013-12-19 to 2013-12-26, 15 records
# Dumped physics:hep-lat from 2013-12-27 to 2013-12-31, 5 records
# Retrieved 1081 records
#
# Writing to arXivMeta_physics--hep-ph_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Dumped physics:hep-ph from 2013-01-01 to 2013-01-08, 78 records
# Dumped physics:hep-ph from 2013-01-09 to 2013-01-16, 95 records
# Dumped physics:hep-ph from 2013-01-17 to 2013-01-24, 87 records
# Dumped physics:hep-ph from 2013-01-25 to 2013-02-01, 75 records
# Dumped physics:hep-ph from 2013-02-02 to 2013-02-09, 64 records
# Dumped physics:hep-ph from 2013-02-10 to 2013-02-17, 53 records
# Dumped physics:hep-ph from 2013-02-18 to 2013-02-25, 72 records
# Dumped physics:hep-ph from 2013-02-26 to 2013-03-05, 83 records
# Dumped physics:hep-ph from 2013-03-06 to 2013-03-13, 69 records
# Dumped physics:hep-ph from 2013-03-14 to 2013-03-21, 123 records
# Dumped physics:hep-ph from 2013-03-22 to 2013-03-29, 111 records
# Dumped physics:hep-ph from 2013-03-30 to 2013-04-06, 83 records
# Dumped physics:hep-ph from 2013-04-07 to 2013-04-14, 90 records
# Dumped physics:hep-ph from 2013-04-15 to 2013-04-22, 97 records
# Dumped physics:hep-ph from 2013-04-23 to 2013-04-30, 90 records
# Dumped physics:hep-ph from 2013-05-01 to 2013-05-08, 109 records
# Dumped physics:hep-ph from 2013-05-09 to 2013-05-16, 100 records
# Dumped physics:hep-ph from 2013-05-17 to 2013-05-24, 101 records
# Dumped physics:hep-ph from 2013-05-25 to 2013-06-01, 1000 records
# Dumped physics:hep-ph from 2013-06-02 to 2013-06-09, 81 records
# Dumped physics:hep-ph from 2013-06-10 to 2013-06-17, 96 records
# Dumped physics:hep-ph from 2013-06-18 to 2013-06-25, 91 records
# Dumped physics:hep-ph from 2013-06-26 to 2013-07-03, 136 records
# Dumped physics:hep-ph from 2013-07-04 to 2013-07-11, 90 records
# Dumped physics:hep-ph from 2013-07-12 to 2013-07-19, 84 records
# Dumped physics:hep-ph from 2013-07-20 to 2013-07-27, 73 records
# Dumped physics:hep-ph from 2013-07-28 to 2013-08-04, 81 records
# Dumped physics:hep-ph from 2013-08-05 to 2013-08-12, 173 records
# Dumped physics:hep-ph from 2013-08-13 to 2013-08-20, 93 records
# Dumped physics:hep-ph from 2013-08-21 to 2013-08-28, 112 records
# Dumped physics:hep-ph from 2013-08-29 to 2013-09-05, 105 records
# Dumped physics:hep-ph from 2013-09-06 to 2013-09-13, 106 records
# Dumped physics:hep-ph from 2013-09-14 to 2013-09-21, 90 records
# Dumped physics:hep-ph from 2013-09-22 to 2013-09-29, 80 records
# Dumped physics:hep-ph from 2013-09-30 to 2013-10-07, 148 records
# Dumped physics:hep-ph from 2013-10-08 to 2013-10-15, 98 records
# Dumped physics:hep-ph from 2013-10-16 to 2013-10-23, 91 records
# Dumped physics:hep-ph from 2013-10-24 to 2013-10-31, 154 records
# Dumped physics:hep-ph from 2013-11-01 to 2013-11-08, 113 records
# Dumped physics:hep-ph from 2013-11-09 to 2013-11-16, 136 records
# Dumped physics:hep-ph from 2013-11-17 to 2013-11-24, 114 records
# Dumped physics:hep-ph from 2013-11-25 to 2013-12-02, 124 records
# Dumped physics:hep-ph from 2013-12-03 to 2013-12-10, 133 records
# Dumped physics:hep-ph from 2013-12-11 to 2013-12-18, 134 records
# Dumped physics:hep-ph from 2013-12-19 to 2013-12-26, 77 records
# Dumped physics:hep-ph from 2013-12-27 to 2013-12-31, 34 records
# Retrieved 5427 records
#
# Writing to arXivMeta_physics--hep-th_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed physics:hep-th at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_physics--math-ph_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed physics:math-ph at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_physics--nlin_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed physics:nlin at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_physics--nucl-ex_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed physics:nucl-ex at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_physics--nucl-th_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed physics:nucl-th at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_physics--physics_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed physics:physics at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_physics--quant-ph_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed physics:quant-ph at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_q-bio_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed q-bio at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_q-fin_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed q-fin at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records
#
# Writing to arXivMeta_stat_from_2013-01-01_to_2013-12-31.txt
# The file will be created
# Failed stat at date_from=2013-01-01, date_until=2013-01-08
# Retrieved 0 records

# %%
year = '2014'

for cat in cats:
    harvest_data(f"{year}-01-01", f"{year}-12-31", cat, by_days=7)
# Out:
# Writing to arXivMeta_cs_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed cs at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_math_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed math at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--astro-ph_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:astro-ph at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--cond-mat_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:cond-mat at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--gr-qc_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:gr-qc at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--hep-ex_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:hep-ex at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--hep-lat_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:hep-lat at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--hep-ph_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:hep-ph at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--hep-th_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:hep-th at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--math-ph_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:math-ph at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--nlin_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:nlin at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--nucl-ex_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:nucl-ex at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--nucl-th_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:nucl-th at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--physics_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:physics at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_physics--quant-ph_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed physics:quant-ph at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_q-bio_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# Failed q-bio at date_from=2014-01-01, date_until=2014-01-07
# Retrieved 0 records
#
# Writing to arXivMeta_q-fin_from_2014-01-01_to_2014-12-31.txt
# The file will be created
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-99ec761c0cb4> in get_data_slice(date_from, date_until)
#      71         try:
# ---> 72             records_count = from_query_to_file()
#      73
#
# <ipython-input-21-99ec761c0cb4> in from_query_to_file()
#      59
# ---> 60             sauce = urllib.request.urlopen(xml_query).read()
#      61             text = str(sauce)
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 503: Retry after specified interval
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-5e62db2e1722> in <module>()
#       2
#       3 for cat in cats:
# ----> 4     harvest_data(f"{year}-01-01", f"{year}-12-31", cat, by_days=7)
#
# <ipython-input-21-99ec761c0cb4> in harvest_data(isoday_0, isoday_1, cat, by_days, overwrite_the_file, file_name, verbose)
#      98
#      99         # get the data
# --> 100         new_records = get_data_slice(date_from, date_until)
#     101
#     102         if new_records == -1 :
#
# <ipython-input-21-99ec761c0cb4> in get_data_slice(date_from, date_until)
#      75
#      76             # wait and try the secod time
# ---> 77             time.sleep(10)
#      78             try:
#      79                 records_count = from_query_to_file()
#
# KeyboardInterrupt:

# %%
year = '2015'

for cat in cats:
    harvest_data(f"{year}-01-01", f"{year}-12-31", cat, by_days=6)

# %%
year = '2016'

for cat in cats:
    harvest_data(f"{year}-01-01", f"{year}-12-31", cat, by_days=5)

# %%
year = '2017'

for cat in cats:
    harvest_data(f"{year}-01-01", f"{year}-12-31", cat, by_days=4)
