# %%
import numpy as np
import pandas as pd
import os

# %%
datapath = os.path.join("data", "")

# %%
oecd = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
oecd = oecd[oecd.INEQUALITY == "TOT"]
oecd = oecd.pivot(index="Country", columns="Indicator", values="Value")
oecd
# Out:
# Indicator        Air pollution  Assault rate  Consultation on rule-making  \
# Country
# Australia                 13.0           2.1                         10.5
# Austria                   27.0           3.4                          7.1
# Belgium                   21.0           6.6                          4.5
# Brazil                    18.0           7.9                          4.0
# Canada                    15.0           1.3                         10.5
# Chile                     46.0           6.9                          2.0
# Czech Republic            16.0           2.8                          6.8
# Denmark                   15.0           3.9                          7.0
# Estonia                    9.0           5.5                          3.3
# Finland                   15.0           2.4                          9.0
# France                    12.0           5.0                          3.5
# ...

# %%
gdp = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")
gdp.rename(columns={"2015": "gdp_per_capita"}, inplace = True)
gdp.index = gdp.Country
gdp
# Out:
#                                                                                               Country  \
# Country
# Afghanistan                                                                               Afghanistan
# Albania                                                                                       Albania
# Algeria                                                                                       Algeria
# Angola                                                                                         Angola
# Antigua and Barbuda                                                               Antigua and Barbuda
# Argentina                                                                                   Argentina
# Armenia                                                                                       Armenia
# Australia                                                                                   Australia
# ...

# %%
LifeSat_Gdp = pd.merge(left=oecd[['Life satisfaction']],
                       right=gdp[['gdp_per_capita']],
                       left_index=True, right_index=True
                      )
LifeSat_Gdp.rename(columns={'Life satisfaction': 'LifeSat',
                            'gdp_per_capita': 'Gdp'
                           },
                   inplace = True
                  )
LifeSat_Gdp.drop(['Brazil', 'Mexico', 'Chile', 'Czech Republic', 'Norway', 'Switzerland', 'Luxembourg'],
                 inplace=True
                )

# %%
import matplotlib.pyplot as plt
LifeSat_Gdp.plot(x='Gdp', y='LifeSat', kind='scatter')
plt.show()

# %% [markdown]
# ## Fit a line (ordinary least squares)

# %%
import sklearn.linear_model
model = sklearn.linear_model.LinearRegression()

y = np.array(LifeSat_Gdp.iloc[:,0]).reshape(-1,1)
X = np.array(LifeSat_Gdp.iloc[:,1]).reshape(-1,1)

model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
LifeSat_Gdp.plot(x='Gdp', y='LifeSat', kind='scatter')
xp = np.linspace(8000, 56000, 2).reshape(-1,1)
yp = model.predict(xp)
plt.plot(xp, yp)
plt.show()

# %%
model.coef_, model.intercept_
# Out:
# (array([[4.91154459e-05]]), array([4.8530528]))

# %% [markdown]
# ### Predict life-satisfaction on Cyprus knowing the GDP

# %%
Cyprus_gdp = gdp.loc["Cyprus"].gdp_per_capita
Cyprus_lifesat_estim = model.predict(gdp.loc["Cyprus"].gdp_per_capita)
Cyprus_gdp, Cyprus_lifesat_estim
# Out:
# (22587.49, array([[5.96244744]]))

# %%
LifeSat_Gdp.plot(x='Gdp', y='LifeSat', kind='scatter')
xp = np.linspace(8000, 56000, 2).reshape(-1,1)
yp = model.predict(xp)
plt.plot(xp, yp)
plt.plot(Cyprus_gdp, Cyprus_lifesat_estim, 'r^')
plt.show()

# %% [markdown]
# ## Let's try regression by one-dimensional kNN in GDP

# %%
import sklearn.neighbors
model_knn = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5)

y = np.array(LifeSat_Gdp.iloc[:,0]).reshape(-1,1)
X = np.array(LifeSat_Gdp.iloc[:,1]).reshape(-1,1)

model_knn.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
Cyprus_lifesat_estim_knn = model_knn.predict(gdp.loc["Cyprus"].gdp_per_capita)
Cyprus_gdp, Cyprus_lifesat_estim_knn
# Out:
# (22587.49, array([[5.58]]))

# %%
LifeSat_Gdp.plot(x='Gdp', y='LifeSat', kind='scatter')
xp = np.linspace(8000, 56000, 200).reshape(-1,1)
yp = model.predict(xp)
yp_knn = model_knn.predict(xp)
plt.plot(xp, yp)
plt.plot(xp, yp_knn, 'k')
plt.plot(Cyprus_gdp, Cyprus_lifesat_estim, 'r^')
plt.plot(Cyprus_gdp, Cyprus_lifesat_estim_knn, 'r^')
plt.show()
